# %% [markdown]
# ### 1B Schets neuraal netwerk
# ![image-2.png](attachment:image-2.png)
#
# Elke pijl heeft zijn eigen weight in dit model behalve de pijl naar Output\
# In elke neuron zit een Bias\
# Na elke neuron zit een activation function

# %% [markdown]
# ### 1C

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Het shallow model werkt niet op deze dataset omdat dit geen simpele lineare scheiding heeft. Deze dataset is dus te complex om met het shallow model op te pakken
