# %% [markdown]
# ### B schets van het neurale netwerk
# ![image.png](attachment:image.png)
#
# Elke pijl heeft zijn eigen weight in dit model behalve de pijl naar Output\
# In elke neuron zit een Bias\
# Na elke neuron zit een activation function
#
# dit netwerk heeft 3 lagen

# %% [markdown]
# ### C
#
# Adam is de optimizer die hier wordt toegepast
#
# Het doel van een optimizer is om het verschil tussen de predictions en de daadwerkelijke uitkomsten zo laag mogelijk te houden.\
# Denk hierbij bijvoorbeeld aan het zo laag mogelijk houden van de loss function.

# %% [markdown]
# ### D
#
# ![image.png](attachment:image.png)
#
# de trainingset heeft een lagere accuracy dan de testset. Wij vermoeden dat dit komt door het kruisje en het rondje die in elkaar zitten\
# \
# In het oorspronkelijke notebook zat een error waardoor de accuracy niet goed werdt geprint, met behulp van ChatGPT hebben we een werkende functie gekregen\
# hieronder de code daarvan
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### E
#
# Ja er is zeker spraken van overfitting, wanneer je naar de afbeelding hieronder kijkt zul je zien\
# dat er heel veel wobbels in de lijn zitten.\
# Dit is een teken dat er te veel lagen of te veel neuronen aanwezig zijn \
# ![image.png](attachment:image.png)
